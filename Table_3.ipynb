# %%
import json
import pandas as pd
from pprint import pprint
import datetime

# %%
dog_datadf = pd.read_csv('cleaned_data.csv')
# dog_datadf
dog_datadf.columns.tolist()
dog_datadf = dog_datadf.set_index('Unnamed: 0', drop = True)
dog_datadf.index.name = None
dog_datadf
# Out:
#        unique_id incident_date                               breed  age  \
# 0           9350    2015-01-01                            pit bull  NaN
# 1             14    2015-01-01  american pit bull terrier/pit bull  NaN
# 2           6829    2015-01-01                            bull dog    3
# 3              4    2015-01-01  american pit bull terrier/pit bull    6
# 4           4043    2015-01-01                         mixed/other   10
# ...          ...           ...                                 ...  ...
# 24982       1292    2022-12-31                             unknown  NaN
# 24983       1293    2022-12-31        yorkshire terrier crossbreed    1
# 24984       1294    2022-12-31                             unknown  NaN
# 24985       1297    2022-12-31                             maltese    6
# 24986       1299    2022-12-31                          cock-a-poo    6
#
#       gender  spay_neuter_status        borough zip_code
# ...

# %%
dogs_data = dog_datadf[['unique_id', 'incident_date', 'breed', 'age', 'gender', 'spay_neuter_status']]
dogs_data
# Out:
#        unique_id incident_date                               breed  age  \
# 0           9350    2015-01-01                            pit bull  NaN
# 1             14    2015-01-01  american pit bull terrier/pit bull  NaN
# 2           6829    2015-01-01                            bull dog    3
# 3              4    2015-01-01  american pit bull terrier/pit bull    6
# 4           4043    2015-01-01                         mixed/other   10
# ...          ...           ...                                 ...  ...
# 24982       1292    2022-12-31                             unknown  NaN
# 24983       1293    2022-12-31        yorkshire terrier crossbreed    1
# 24984       1294    2022-12-31                             unknown  NaN
# 24985       1297    2022-12-31                             maltese    6
# 24986       1299    2022-12-31                          cock-a-poo    6
#
#       gender  spay_neuter_status
# 0          M               False
# 1          U               False
# ...

# %%
dogs_data.to_csv('dogs_data.csv')

# %%
dogs_datadf = dogs_data
mask = dogs_datadf[['unique_id', 'breed', 'age', 'gender', 'spay_neuter_status']]
mask
# Out:
#        unique_id                               breed  age gender  \
# 0           9350                            pit bull  NaN      M
# 1             14  american pit bull terrier/pit bull  NaN      U
# 2           6829                            bull dog    3      F
# 3              4  american pit bull terrier/pit bull    6      M
# 4           4043                         mixed/other   10      M
# ...          ...                                 ...  ...    ...
# 24982       1292                             unknown  NaN      U
# 24983       1293        yorkshire terrier crossbreed    1      M
# 24984       1294                             unknown  NaN      U
# 24985       1297                             maltese    6      F
# 24986       1299                          cock-a-poo    6      M
#
#        spay_neuter_status
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                    True
# ...
