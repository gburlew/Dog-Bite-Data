# %%
import json
import pandas as pd
from pprint import pprint
import datetime

dog_location = pd.read_csv('cleaned_data.csv')
dog_location.columns.tolist()
dog_location = dog_location.set_index('Unnamed: 0', drop=True)
dog_location.index.name = None
dog_location
# Out:
#        unique_id incident_date                               breed  age  \
# 0           9350    2015-01-01                            pit bull  NaN
# 1             14    2015-01-01  american pit bull terrier/pit bull  NaN
# 2           6829    2015-01-01                            bull dog    3
# 3              4    2015-01-01  american pit bull terrier/pit bull    6
# 4           4043    2015-01-01                         mixed/other   10
# ...          ...           ...                                 ...  ...
# 24982       1292    2022-12-31                             unknown  NaN
# 24983       1293    2022-12-31        yorkshire terrier crossbreed    1
# 24984       1294    2022-12-31                             unknown  NaN
# 24985       1297    2022-12-31                             maltese    6
# 24986       1299    2022-12-31                          cock-a-poo    6
#
#       gender  spay_neuter_status        borough zip_code
# 0          M               False  Staten Island    10301
# 1          U               False       Brooklyn    11220
# 2          F               False         Queens      NaN
# 3          M               False       Brooklyn    11221
# 4          M                True      Manhattan    10065
# ...      ...                 ...            ...      ...
# 24982      U               False          Bronx    10463
# 24983      M               False          Bronx    10452
# 24984      U               False          Bronx    10469
# 24985      F                True          Bronx    10456
# 24986      M               False          Bronx    10461
#
# [24987 rows x 8 columns]

# %%
location_df = dog_location[['unique_id', 'incident_date', 'borough', 'zip_code']]
location_df
# Out:
#        unique_id incident_date        borough zip_code
# 0           9350    2015-01-01  Staten Island    10301
# 1             14    2015-01-01       Brooklyn    11220
# 2           6829    2015-01-01         Queens      NaN
# 3              4    2015-01-01       Brooklyn    11221
# 4           4043    2015-01-01      Manhattan    10065
# ...          ...           ...            ...      ...
# 24982       1292    2022-12-31          Bronx    10463
# 24983       1293    2022-12-31          Bronx    10452
# 24984       1294    2022-12-31          Bronx    10469
# 24985       1297    2022-12-31          Bronx    10456
# 24986       1299    2022-12-31          Bronx    10461
#
# [24987 rows x 4 columns]

# %%
location_df.to_csv("dog_location.csv")

# %%
grouped = location_df.groupby('borough')['zip_code'].unique().reset_index()
grouped.columns = ['borough', 'zip_codes']
grouped
# Out:
#          borough                                          zip_codes
# 0          Bronx  [10459, nan, 10466, 10464, 10461, 10451, 10469...
# 1       Brooklyn  [11220, 11221, nan, 11249, 11238, 11207, 11215...
# 2      Manhattan  [10065, 10026, 10128, 10010, nan, 10004, 10007...
# 3         Queens  [nan, 11434, 11412, 11433, 11428, 11361, 11357...
# 4  Staten Island  [10301, 10302, 10304, 10310, nan, 10307, 10312...
