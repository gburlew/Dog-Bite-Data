# %%
import folium

# create folium map for New York, add markers for 5 boroughs, customize marker.
mymap = folium.Map([40.730610, -73.935242], zoom_start=10)

locations = [[40.776676, -73.971321, 'Manhatten', 'marker2.png'], 
             [40.650002,	-73.949997, 'Brooklyn', 'marker2.png'], 
             [40.579021, -74.151535, 'Staten Island', 'marker2.png'], 
             [40.837048, -73.865433, 'Bronx', 'marker2.png'], 
             [40.742054, -73.769417, 'Queens', 'marker2.png']]

for loc in locations:
    custom_icon = folium.CustomIcon(icon_image=loc[3], icon_size=(50, 50))
    folium.Marker(location=[loc[0], loc[1]], icon=custom_icon, popup=loc[2]).add_to(mymap)

mymap.save("Folium_Map.html")

# %%
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b5649e9900d8203d4c94719d1752430 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b5649e9900d8203d4c94719d1752430&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b5649e9900d8203d4c94719d1752430 = L.map(
#                 &quot;map_0b5649e9900d8203d4c94719d1752430&quot;,
#                 {
#                     center: [40.73061, -73.935242],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19abc22251ded52de1dc6916ba7a5e8f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_19abc22251ded52de1dc6916ba7a5e8f.addTo(map_0b5649e9900d8203d4c94719d1752430);
#
#
#             var marker_5eeb2e252c8724d3575d72bfa443e8d6 = L.marker(
#                 [40.776676, -73.971321],
#                 {}
#             ).addTo(map_0b5649e9900d8203d4c94719d1752430);
#
#
#         var custom_icon_928171f918baa89f346b99eed9ee52fb = L.icon({&quot;iconSize&quot;: [50, 50], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_5eeb2e252c8724d3575d72bfa443e8d6.setIcon(custom_icon_928171f918baa89f346b99eed9ee52fb);
#
#
#         var popup_01cd825504aa32ad85c0b6b502eabef0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_61dbb21e521173df812f2a45cfeed513 = $(`&lt;div id=&quot;html_61dbb21e521173df812f2a45cfeed513&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manhatten&lt;/div&gt;`)[0];
#                 popup_01cd825504aa32ad85c0b6b502eabef0.setContent(html_61dbb21e521173df812f2a45cfeed513);
#
#
#
#         marker_5eeb2e252c8724d3575d72bfa443e8d6.bindPopup(popup_01cd825504aa32ad85c0b6b502eabef0)
#         ;
#
#
#
#
#             var marker_43bc491a1d721ac572ef4eaf796cd009 = L.marker(
#                 [40.650002, -73.949997],
#                 {}
#             ).addTo(map_0b5649e9900d8203d4c94719d1752430);
#
#
#         var custom_icon_b324104f3911a3b4bcb4972c8ea34d22 = L.icon({&quot;iconSize&quot;: [50, 50], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_43bc491a1d721ac572ef4eaf796cd009.setIcon(custom_icon_b324104f3911a3b4bcb4972c8ea34d22);
#
#
#         var popup_4e077c0d82e0456de78a64b26c407016 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bf76f810d2f9a1b7c2047eb7a0ca2d9e = $(`&lt;div id=&quot;html_bf76f810d2f9a1b7c2047eb7a0ca2d9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brooklyn&lt;/div&gt;`)[0];
#                 popup_4e077c0d82e0456de78a64b26c407016.setContent(html_bf76f810d2f9a1b7c2047eb7a0ca2d9e);
#
#
#
#         marker_43bc491a1d721ac572ef4eaf796cd009.bindPopup(popup_4e077c0d82e0456de78a64b26c407016)
#         ;
#
#
#
#
#             var marker_cbd6e847251525f8325c432d133c6b37 = L.marker(
#                 [40.579021, -74.151535],
#                 {}
#             ).addTo(map_0b5649e9900d8203d4c94719d1752430);
#
#
#         var custom_icon_87fd810ef2222a14ea6bb165cb37b704 = L.icon({&quot;iconSize&quot;: [50, 50], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_cbd6e847251525f8325c432d133c6b37.setIcon(custom_icon_87fd810ef2222a14ea6bb165cb37b704);
#
#
#         var popup_27edfb6305022fa8c9f32e1fa6b04e81 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d1dfafea042104d275ac7184b88edae3 = $(`&lt;div id=&quot;html_d1dfafea042104d275ac7184b88edae3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Staten Island&lt;/div&gt;`)[0];
#                 popup_27edfb6305022fa8c9f32e1fa6b04e81.setContent(html_d1dfafea042104d275ac7184b88edae3);
#
#
#
#         marker_cbd6e847251525f8325c432d133c6b37.bindPopup(popup_27edfb6305022fa8c9f32e1fa6b04e81)
#         ;
#
#
#
#
#             var marker_0b0309e8f73fd6176f7d94d986511431 = L.marker(
#                 [40.837048, -73.865433],
#                 {}
#             ).addTo(map_0b5649e9900d8203d4c94719d1752430);
#
#
#         var custom_icon_afa7c6a631044207d9148458c1b1ab16 = L.icon({&quot;iconSize&quot;: [50, 50], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_0b0309e8f73fd6176f7d94d986511431.setIcon(custom_icon_afa7c6a631044207d9148458c1b1ab16);
#
#
#         var popup_93cc3ac79a8d87d0bf4dc4cbbc11f670 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e6731c08703b23d05c638b304d6a10b2 = $(`&lt;div id=&quot;html_e6731c08703b23d05c638b304d6a10b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#                 popup_93cc3ac79a8d87d0bf4dc4cbbc11f670.setContent(html_e6731c08703b23d05c638b304d6a10b2);
